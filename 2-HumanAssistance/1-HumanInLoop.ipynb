# %% [markdown]
# ## Human in loop

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain.chat_models import init_chat_model
llm=ChatGroq(model="openai/gpt-oss-120b")
llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.1', 'langchain': '1.3.18'}}, profile={'name': 'GPT OSS 120B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x116e15a90>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x116e16490>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from typing import Annotated

from langchain_tavily import TavilySearch
from langchain_core.tools import tool
from typing_extensions import TypedDict

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition

from langgraph.types import Command, interrupt ## for hil

class State(TypedDict):
    messages: Annotated[list, add_messages]

graph_builder = StateGraph(State)

@tool
def human_assistance(query: str) -> str:
    """Request assistance from a human."""
    human_response = interrupt({"query": query})
    return human_response["data"]

tool = TavilySearch(max_results=2)
tools = [tool, human_assistance]
llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    message = llm_with_tools.invoke(state["messages"])
    # Because we will be interrupting during tool execution,
    # we disable parallel tool calling to avoid repeating any
    # tool invocations when we resume.
    
    return {"messages": [message]}

graph_builder.add_node("chatbot", chatbot)

tool_node = ToolNode(tools=tools)
graph_builder.add_node("tools", tool_node)

graph_builder.add_conditional_edges(
    "chatbot",
    tools_condition,
)
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# %%
memory = MemorySaver()

graph = graph_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
user_input = "I need some expert guidance and assistance for building an AI agent. Could you request assistance for me?"
config = {"configurable": {"thread_id": "1"}}

events = graph.stream(
    {"messages": user_input},
    config,
    stream_mode="values",
)
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# I need some expert guidance and assistance for building an AI agent. Could you request assistance for me?
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (fc_f3d9f6c9-5e13-4cea-8291-e9be7cc585de)
#  Call ID: fc_f3d9f6c9-5e13-4cea-8291-e9be7cc585de
#   Args:
#     query: User needs expert guidance and assistance for building an AI agent. Please provide assistance.
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (fc_f3d9f6c9-5e13-4cea-8291-e9be7cc585de)
#  Call ID: fc_f3d9f6c9-5e13-4cea-8291-e9be7cc585de
#   Args:
#     query: User needs expert guidance and assistance for building an AI agent. Please provide assistance.

# %%
human_response = (
    "We, the experts are here to help! We'd recommend you check out LangGraph to build your agent."
    " It's much more reliable and extensible than simple autonomous agents."
)

human_command = Command(resume={"data": human_response}) ##command is used to inout the human message

events = graph.stream(human_command, config, stream_mode="values")
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (fc_f3d9f6c9-5e13-4cea-8291-e9be7cc585de)
#  Call ID: fc_f3d9f6c9-5e13-4cea-8291-e9be7cc585de
#   Args:
#     query: User needs expert guidance and assistance for building an AI agent. Please provide assistance.
# ================================= Tool Message =================================
# Name: human_assistance
#
# We, the experts are here to help! We'd recommend you check out LangGraph to build your agent. It's much more reliable and extensible than simple autonomous agents.
# ================================== Ai Message ==================================
#
# Absolutely—happy to help you get started building an AI agent! Below is a quick‑start guide that expands on the recommendation you received and points you toward the most useful resources, tools, and best‑practice patterns.
#
# ---
#
# ## 1️⃣ Choose a Framework: **LangGraph** (highly recommended)
#
# | Why LangGraph? | What it Gives You |
# |----------------|-------------------|
# | **Composable** – Build complex multi‑step workflows from simple nodes (functions, LLM calls, tools). | **Graph‑based execution engine** that handles branching, loops, and conditional logic. |
# | **Stateful** – Persistent node state makes it easy to track conversation context, task progress, or external data. | **Built‑in memory & checkpointing** (Redis, SQLite, DynamoDB, etc.). |
# | **Extensible** – Plug in any Python function, API client, or custom tool. | **Tool‑binding API** for tool use, tool calling, and tool output parsing. |
# | **Observability** – Automatic logging, tracing, and visual graph rendering. | **Dashboard & CLI** for debugging and monitoring runs. |
# | **Community & Docs** – Actively maintained, many examples (agents, assistants, autonomous loops). | **Tutorials, templates, and a vibrant Discord/Slack community**. |
#
# > **Bottom line:** If you need an agent that can handle multi‑turn reasoning, tool usage, and dynamic control flow, LangGraph is currently the most robust open‑source option. It’s also compatible with any LLM provider (OpenAI, Anthropic, Cohere, local models, etc.).
#
# ### Quick‑start Installation
#
# ```bash
# # Create a fresh environment
# python -m venv .venv && source .venv/bin/activate
#
# # Install LangGraph and a LLM provider (example: OpenAI)
# pip install langgraph openai
# ```
#
# ---
#
# ## 2️⃣ Sketch Your Agent’s Architecture
#
# 1. **Define the Goal** – What does the agent need to accomplish? (e.g., “research and summarize recent AI papers,” “schedule meetings,” “answer technical support queries.”)
#
# 2. **Identify Required Tools** – List any external services the agent will call:
#    - Web search (e.g., Tavily, SerpAPI)
#    - Database / knowledge base (SQL, Pinecone, Weaviate)
#    - APIs (calendar, email, GitHub, etc.)
#    - Custom Python functions (data cleaning, calculations)
#
# 3. **Map the Control Flow** – Use a simple flowchart or pseudocode:
#    - **Start → Input Parsing → Decision Node → Tool Calls → LLM Reasoning → Output**
#    - Add loops for “retry on failure” or “ask clarification.”
#
# 4. **State Model** – Decide what information must persist across turns:
#    - `conversation_history`
#    - `task_status`
#    - `intermediate_results` (e.g., search snippets, retrieved docs)
#
# ---
#
# ## 3️⃣ Implement a Minimal Working Example
#
# Below is a compact, fully runnable example that shows a LangGraph agent which:
#
# - Takes a user query.
# - Uses a web‑search tool (Tavily) to fetch top results.
# - Summarizes the findings with an LLM.
# - Returns a concise answer.
#
# ```python
# # agent.py
# import os
# from langgraph.graph import StateGraph, START, END
# from langgraph.prebuilt import ToolNode
# from openai import OpenAI
# from tavily import TavilyClient   # pip install tavily-python
#
# # ---------- LLM ----------
# client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
#
# def llm_call(prompt: str) -> str:
#     resp = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": prompt}],
#         temperature=0.2,
#     )
#     return resp.choices[0].message.content
#
# # ---------- Tool ----------
# tavily = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
#
# def web_search(state):
#     query = state["user_query"]
#     results = tavily.search(query, max_results=5)
#     # Keep only titles + snippets for brevity
#     formatted = "\n".join([f"- {r['title']}: {r['content']}" for r in results])
#     return {"search_results": formatted}
#
# # ---------- Nodes ----------
# def router(state):
#     """Decide whether we need to search or just answer directly."""
#     if "search_results" not in state:
#         return "search"
#     return "summarize"
#
# def summarize(state):
#     prompt = f"""You are an expert AI assistant. Using the following search results, answer the user’s question concisely.
#
# User question: {state["user_query"]}
#
# Search results:
# {state["search_results"]}
#
# Answer (max 3 sentences):"""
#     answer = llm_call(prompt)
#     return {"final_answer": answer}
#
# # ---------- Graph ----------
# workflow = StateGraph("AgentState")
# workflow.add_node("router", router)
# workflow.add_node("search", ToolNode(web_search))
# workflow.add_node("summarize", summarize)
#
# workflow.add_edge(START, "router")
# workflow.add_conditional_edges(
#     "router",
#     lambda s: s["next"],   # router returns the next node name
#     {"search": "search", "summarize": "summarize"},
# )
# workflow.add_edge("search", "summarize")
# workflow.add_edge("summarize", END)
#
# app = workflow.compile()
#
# # ---------- Run ----------
# if __name__ == "__main__":
#     user_query = input("🗣️  Ask me anything: ")
#     result = app.invoke({"user_query": user_query})
#     print("\n🤖 Answer:", result["final_answer"])
# ```
#
# **What this does**
#
# | Step | Action |
# |------|--------|
# | `router` | Checks if we already have `search_results`. If not, jumps to `search`. |
# | `search` (ToolNode) | Calls Tavily to fetch web results. |
# | `summarize` | Prompts the LLM to synthesize a short answer. |
# | `END` | Returns the final answer. |
#
# You can expand this skeleton by adding more tools, loops, or branching logic.
#
# ---
#
# ## 4️⃣ Add Advanced Features
#
# | Feature | How to Implement (LangGraph) |
# |---------|------------------------------|
# | **Memory / Long‑term context** | Use `langgraph.checkpoint` with a persistent store (Redis, SQLite). Store `conversation_history` and retrieve it in each turn. |
# | **Tool calling with JSON schema** | Define a `ToolNode` that returns a JSON payload; let the LLM output a structured request (e.g., `"action": "search", "params": {...}`) and route accordingly. |
# | **Self‑reflection / Re‑planning** | Add a “review” node that asks the LLM to evaluate the answer quality and decide whether to loop back for another tool call. |
# | **Parallel tool execution** | Use `workflow.add_parallel_edges([...])` to fire multiple API calls simultaneously and merge results later. |
# | **Rate limiting & retries** | Wrap tool functions with `tenacity` or LangGraph’s built‑in retry policies. |
# | **Observability** | Enable LangGraph’s built‑in logging: `workflow.set_logger(my_logger)` or use the UI (`langgraph viz`). |
# | **Safety filters** | Insert a “moderation” node that runs OpenAI’s moderation endpoint before sending any LLM output to the user. |
#
# ---
#
# ## 5️⃣ Testing & Debugging Tips
#
# 1. **Unit‑test each node** – Write plain Python tests for `web_search`, `summarize`, etc., using `pytest`. Mock external APIs with `responses` or `unittest.mock`.
# 2. **Run step‑by‑step** – Use `app.get_state()` after each node to inspect intermediate state.
# 3. **Visualize the graph** – `from langgraph.visualize import draw; draw(app)` gives you a PNG/HTML of the workflow.
# 4. **Log everything** – Include timestamps, node names, and payload sizes. This is crucial for production monitoring.
# 5. **Stress‑test** – Simulate many concurrent invocations (e.g., `locust` or `hey`) to see how the checkpoint store handles load.
#
# ---
#
# ## 6️⃣ Deployment Options
#
# | Platform | Why It Works |
# |----------|--------------|
# | **Docker + Kubernetes** | Containerize the agent, scale horizontally, mount a secret store for API keys. |
# | **Serverless (AWS Lambda / Cloudflare Workers)** | Low‑latency, pay‑per‑use; good for occasional queries. |
# | **Managed LLM APIs** | Keep the heavy lifting (model inference) in the cloud; only your orchestration runs locally. |
# | **Edge Functions** | For ultra‑fast responses on simple tool‑calling agents (e.g., static knowledge‑base lookups). |
#
# A minimal Dockerfile for the example above:
#
# ```Dockerfile
# FROM python:3.12-slim
# WORKDIR /app
# COPY requirements.txt .
# RUN pip install -r requirements.txt
# COPY agent.py .
# ENV OPENAI_API_KEY=***
# ENV TAVILY_API_KEY=***
# CMD ["python", "agent.py"]
# ```
#
# ---
#
# ## 7️⃣ Learning Resources & Communities
#
# | Resource | Link |
# |----------|------|
# | **LangGraph Docs** (quick‑start, advanced patterns) | https://langchain.com/langgraph |
# | **LangGraph GitHub Repo** (examples, templates) | https://github.com/langchain-ai/langgraph |
# | **LangChain Community Discord** (active #langgraph channel) | https://discord.gg/langchain |
# | **OpenAI Function‑Calling Guide** (useful for tool schemas) | https://platform.openai.com/docs/guides/function-calling |
# | **Tavily API Docs** (search tool) | https://tavily.com/docs |
# | **LLM‑Ops Playbook** (deployment, monitoring) | https://github.com/llm-ops/playbook |
# | **“Building Agents with LangGraph”** (YouTube tutorial series) | Search on YouTube for the series name. |
#
# ---
#
# ## 8️⃣ Next Steps for You
#
# 1. **Set up your environment** (Python venv, install LangGraph, OpenAI, Tavily).
# 2. **Run the minimal example** above to verify the end‑to‑end flow.
# 3. **Iterate:** Add a second tool (e.g., a calendar API) and expand the graph with a new branch.
# 4. **Persist state** with Redis or SQLite, then test multi‑turn conversations.
# 5. **Deploy** to a container or serverless platform and expose an HTTP endpoint (FastAPI + `uvicorn` works nicely).
#
# ---
#
# ### 🎯 TL;DR
#
# - **LangGraph** is the go‑to framework for building reliable, extensible AI agents.
# - Start with a simple graph (router → tool → summarizer) and expand.
# - Leverage tool nodes, persistent state, and conditional edges to handle complex workflows.
# - Use the resources and community links above for deeper dives, and feel free to ask follow‑up questions on any specific part (e.g., state management, tool integration, deployment).
#
# Let me know which part you’d like to dive deeper into—whether it’s wiring up a particular API, adding memory, or setting up production monitoring—and I can provide concrete code snippets or architectural guidance! 🚀
